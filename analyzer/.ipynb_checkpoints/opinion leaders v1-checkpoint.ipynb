# %%
import requests
import json
import pymongo
from pymongo import MongoClient

# %%
db_username = 'sveta'
db_password = 'Makhela123'

# %%
db = MongoClient("mongodb+srv://" + db_username + ":" + db_password + "@makhela-qvsh8.mongodb.net/Makhela")

# %%
mydb = db["Makhela"]

# %%
mycol = mydb["opinion_leaders"].find()

# %%
opinion_leaders = []
[opinion_leaders.append(i) for i in mycol]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
opinion_leaders
# Out:
# [{'_id': ObjectId('5e4fe236f3d95c3a7b5f3b9f'),
#   'full_name': 'Dalia Dassa Kaye',
#   'twitter_id': 2696666707,
#   'twitter_screen_name': 'dassakaye',
#   'twitter_created_at': datetime.datetime(2014, 7, 31, 21, 24, 12),
#   'twitter_description': 'Director of the Center for Middle East Public Policy (CMEPP) at the RAND Corporation',
#   'twitter_followers_count': 3489,
#   'twitter_friends_count': 403,
#   'twitter_location': 'Santa Monica, CA',
#   'new_leader': False,
#   'twitter_statuses_count': 3660,
#   'level_of_certainty': 2,
#   'twitter_profile_image': 'http://pbs.twimg.com/profile_images/494962622597300224/QeFwiaKH_400x400.jpeg',
#   'community_following': [30181014,
#    30181014,
#    22803302,
#    22803302,
#    2759399473,
#    2759399473,
#    1227326168,
#    1227326168,
#    2190601093,
#    2190601093,
#    43380129,
#    43380129,
#    1515812534,
#    1515812534,
#    482120066,
#    482120066,
#    2739262472,
#    2739262472,
#    1387074108,
# ...

# %%
len(opinion_leaders)
# Out:
# 60

# %%
opinion_leaders[0]
# Out:
# {'_id': ObjectId('5e4fe236f3d95c3a7b5f3b9f'),
#  'full_name': 'Dalia Dassa Kaye',
#  'twitter_id': 2696666707,
#  'twitter_screen_name': 'dassakaye',
#  'twitter_created_at': datetime.datetime(2014, 7, 31, 21, 24, 12),
#  'twitter_description': 'Director of the Center for Middle East Public Policy (CMEPP) at the RAND Corporation',
#  'twitter_followers_count': 3489,
#  'twitter_friends_count': 403,
#  'twitter_location': 'Santa Monica, CA',
#  'new_leader': False,
#  'twitter_statuses_count': 3660,
#  'level_of_certainty': 2,
#  'twitter_profile_image': 'http://pbs.twimg.com/profile_images/494962622597300224/QeFwiaKH_400x400.jpeg',
#  'community_following': [30181014,
#   30181014,
#   22803302,
#   22803302,
#   2759399473,
#   2759399473,
#   1227326168,
#   1227326168,
#   2190601093,
#   2190601093,
#   43380129,
#   43380129,
#   1515812534,
#   1515812534,
#   482120066,
#   482120066,
#   2739262472,
#   2739262472,
#   1387074108,
#   1387074108,
#   376435807,
# ...

# %%
# xx = mydb["opinion_leaders"].find({ "twitter_id": 480678403 })

# %%
import networkx as nx
G = nx.DiGraph()

# %%
graph = []
for leader in opinion_leaders:
    try:
#         G.add_node(1, time='5pm')
        G.add_node(leader['twitter_id'],full_name=leader['full_name'],
#                    twitter_screen_name=leader['twitter_screen_name'],
#                    twitter_created_at=leader['twitter_created_at'],
#                    twitter_description=leader['twitter_description'],
#                   twitter_followers_count=leader['twitter_followers_count'],
#                   twitter_friends_count=leader['twitter_friends_count'],
#                   twitter_location=leader['twitter_location'],
#                   new_leader=leader['new_leader'],
#                   twitter_statuses_count=leader['twitter_statuses_count'],
#                   level_of_certainty=leader['level_of_certainty'],
#                   twitter_profile_image=leader['twitter_profile_image'],
                  community_following=leader['community_following'])
        graph.append(leader)
    except:
        print(leader)
# Out:
# {'_id': ObjectId('5e4fe236f3d95c3a7b5f3ba5'), 'full_name': 'Anthony Cordesman', 'level_of_certainty': 0, 'new_leader': False, 'lock': False}
# {'_id': ObjectId('5e4fe237f3d95c3a7b5f3ba9'), 'full_name': 'Ephraim Asculai', 'level_of_certainty': 0, 'new_leader': False, 'lock': False}
# {'_id': ObjectId('5e4fe238f3d95c3a7b5f3bb5'), 'full_name': 'Sima Schein', 'level_of_certainty': 0, 'new_leader': False, 'lock': False}
# {'_id': ObjectId('5e4fe239f3d95c3a7b5f3bb9'), 'full_name': 'Shahram Chubin', 'level_of_certainty': 0, 'new_leader': False, 'lock': False}
# ...

# %%
G.nodes.data()
# Out:
# NodeDataView({2696666707: {'full_name': 'Dalia Dassa Kaye', 'community_following': [30181014, 30181014, 22803302, 22803302, 2759399473, 2759399473, 1227326168, 1227326168, 2190601093, 2190601093, 43380129, 43380129, 1515812534, 1515812534, 482120066, 482120066, 2739262472, 2739262472, 1387074108, 1387074108, 376435807, 376435807, 49702592, 49702592, 42176166, 42176166, 47156708, 47156708, 475454826, 475454826, 48906364, 48906364, 480678403, 480678403, 1114663532, 1114663532, 488772327, 488772327, 61051322, 61051322, 541858751, 541858751]}, 482120066: {'full_name': 'Mark Fitzpatrick', 'community_following': [480678403, 480678403, 910253568397053952, 910253568397053952, 48252327, 48252327, 61051322, 61051322, 2696666707, 2696666707, 43380129, 43380129, 1227326168, 1227326168, 1151625187, 1151625187, 475454826, 475454826, 47156708, 47156708, 376435807, 376435807, 541858751, 541858751, 49702592, 49702592, 22803302, 22803302]}, 1589253019: {'full_name': 'Richard (Dick) Sokolsky', 'communi
# ...

# %%
len(graph)

# G.add_edges_from([(3, 4), (4, 5)], color='red')
# Out:
# 26

# %%
try:
    for g in graph:
        for c in g['community_following']:  
            G.add_edges_from((g, c), color='red')
except:
    None

# %%
import matplotlib.pyplot as plt

# %%
G = nx.dodecahedral_graph()
nx.draw(G)
nx.draw(G, pos=nx.spring_layout(G))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
plt.draw()
