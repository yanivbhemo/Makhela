# %%
import tweepy
import json
import requests
import pymongo
from pprint import pprint
#import dnspython

# %%
## DB Connection ##
###DONT FORGET TO REMOVE PASSWORD###
client = pymongo.MongoClient("mongodb+srv://yaniv:<password>@makhela-qvsh8.mongodb.net/test?retryWrites=true&w=majority")
db = client.search_stock
# Out:
# Database(MongoClient(host=['makhela-shard-00-02-qvsh8.mongodb.net:27017', 'makhela-shard-00-01-qvsh8.mongodb.net:27017', 'makhela-shard-00-00-qvsh8.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='Makhela-shard-0', ssl=True, retrywrites=True, w='majority'), 'search_stock')

# %%
## Twitter connection ##
consumer_key = s
consumer_secret = 
access_token = 
access_token_secret = 
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
influencers_names = ["ArianeTabatabai","SuzanneMaloney","MehdiKhalaji","Alireza Nader","Dalia Dassa Kaye","Karim Sadjadpour","Richard (Dick) Sokolsky","George Perkovich","Mark Hibbs","Suzanne DiMaggio","Mark Dubowitz","Reuel Mark Gerecht","Richard Goldberg","Olli Heinonen","Pierre Goldschmidt","David Albright","Emanuele Ottolenghi","Juan Zarate","Robert Einhorn","Djavad Salehi-Isfahani","Norman T. Roule","Dennis B. Ross","Colin Kahl","Jon B. Wolfstahl","Gary Samore","Jeffrey Lewis","Ray Takeyh","Vali Nasr","Graham Allison","Michael Eisenstadt","Barbara A. Leaf","Patrick Clawson","Anthony Cordesman","Barbara Slavin","Trita Parsi","Mohammad Ali Shabani","Ellie Geranmayeh","Esfandyar Batmanghelidj","Ali Vaez","Shahram Chubin","Michael Eisenstadt","Ali Alfoneh","Matthew Kroenig","Barbara Slavin","Holly Dagres","Jerrold D.Green","John Calabrese","William Yong","Ahmad Majidyar","Afshon Ostovar","Mark Fitzpatrick","Kenneth M. Pollack","Michael Elleman","Raz  Zimmt","Tal Inbar","Uzi Rubin","Sima Schein","Amos Yadlin","Emily Landau","Ephraim Asculai","Ariel (Eli) Levite"]
for person in influencers_names:
    print("Search for: " + person)
    try:
        user = api.get_user(person)
        print("Found! User id: " + str(user.id))
    except tweepy.TweepError as e:
        pprint(e)  # prints 34
        break
# Out:
# Search for: ArianeTabatabai
# Found! User id: 43380129
# Search for: SuzanneMaloney
# Found! User id: 217490159
# Search for: MehdiKhalaji
# Found! User id: 947868741454282752
# Search for: Alireza Nader
# TweepError([{'code': 50, 'message': 'User not found.'}])

# %%
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# In 1 hour at 1PM EST Join James Governor, Redmonk Analyst and Co-founder, and Erez Rusovsky, Director of Product Ma… https://t.co/NlDzE6Rssl
# סייבר ניישן 2019: המספרים מאחורי תעשיית הסייבר הישראלית
# https://t.co/L1esLpRein
# Latest from #containerjournal LightStep Announces Solution to Empower Developers with the Fastest Way to Identify P… https://t.co/PL5SsxTJj1
# Take your #DevOps fingerprint to see if you have the skills to work in a DevOps team. The scan comprises of 24 ques… https://t.co/SrxD73Hsso
# 👀 Streaming live at 18:30!
#
# Don't miss @idomdavis speaking at @redgate! https://t.co/2Jh2TA24kQ
# RT @reselbob: A World of Unmet Needs https://t.co/mloagd4JjQ via @devopsdotcom
# RT @dhinchcliffe: How to build a #cloud center of excellence
# https://t.co/Cz1SXctRNL
# Motivation: Because 83% of enterprise workloads will e…
# RT @FastlyJapan: Fastly CTO の @tbmcmullen が、Rust、HTTP/2、 #wasm の進化と2020年におけるその意味について説明します。@devopsdotcom で公開されたこちらの記事をご覧ください : https://t.co/…
# RT @chef: "Latest Chef Habitat Release Embraces On-Premises IT" - Read more from @devopsdotcom. https://t.co/U05E6lqFFQ
# RT @ConvergeSol: Earning an AWS Developer Associate Certification....
# https://t.co/CH54H7WcNG
#
# #AWS #amazonwebservices #awscommunity  #AWS…
# RT @farwa_sajjad96: Implementing DevOps Goes Beyond Technology https://t.co/CGTZnNfEL9 via @devopsdotcom
# RT @NicolasF53: F5 Networks Launches Next-Gen ADC Based on NGINX https://t.co/TAIRpfqMIp via @devopsdotcom
# RT @rahulmuthu80: How to Monitor AWS Resources using Cloudwatch Alarm,
# @devopsdotcom @DevOpsSummit @awscloud @Devops_AWS
# 1)create Cloudwat…
# RT @m0jfp: "@F5Networks Launches Next-Gen ADC Based on @NGINX": https://t.co/MxALwEKuBl via @devopsdotcom #NGINX
# RT @Rosenchild: #DevOps 2020
#
# Achieving #Software #Application #Health through Integrated Application Performance Management - #APM and #Mo…
# RT @HubBucket: 🥇#DevOps2020
#
# Achieving #Software #Application #Health through Integrated Application Performance Management - #APM and #Mon…
# RT @Traininngdotcom: Four DevOps Trends for 2020 https://t.co/e4s0gXbmTn #digitalmarketing #trendingnews #devops #latestnews @DigitalColmer…
# RT @CPSGroupUK: To what extent do you consider the risk of #opensource #software? https://t.co/sGMg5Zfx0r @devopsdotcom #devops #developmen…
# "חכה חכה": 117 אימוג'י חדשים שיגיעו ב-2020 https://t.co/StZAj9GC5u

# %%
user_id = api.get_user("realdonaldtrump").id

# %%
user_tweets = api.user_timeline(user_id,count=1)

# %%
print(user_tweets)
# Out:
# [Status(_api=<tweepy.api.API object at 0x00F090D0>, _json={'created_at': 'Thu Jan 30 17:15:53 +0000 2020', 'id': 1222931452486148097, 'id_str': '1222931452486148097', 'text': 'RT @realDonaldTrump: https://t.co/66006PDuKf', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [3, 19]}], 'urls': [], 'media': [{'id': 1090092682381348864, 'id_str': '1090092682381348864', 'indices': [21, 44], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1090092682381348864/pu/img/4DVLQrnjgHsIyBZt.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1090092682381348864/pu/img/4DVLQrnjgHsIyBZt.jpg', 'url': 'https://t.co/66006PDuKf', 'display_url': 'pic.twitter.com/66006PDuKf', 'expanded_url': 'https://twitter.com/thebradfordfile/status/1090094029109366784/video/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}, 'source_status_id': 1090094029109366784, 'source_status_id_str': '1090094029109366784', 'source_user_id': 3406938525, 'source_user_id_str': '3406938525', 'features': {}}]}, 'extended_entities': {'media': [{'id': 1090092682381348864, 'id_str': '1090092682381348864', 'indices': [21, 44], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1090092682381348864/pu/img/4DVLQrnjgHsIyBZt.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1090092682381348864/pu/img/4DVLQrnjgHsIyBZt.jpg', 'url': 'https://t.co/66006PDuKf', 'display_url': 'pic.twitter.com/66006PDuKf', 'expanded_url': 'https://twitter.com/thebradfordfile/status/1090094029109366784/video/1', 'type': 'video', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}, 'source_status_id': 1090094029109366784, 'source_status_id_str': '1090094029109366784', 'source_user_id': 3406938525, 'source_user_id_str': '3406938525', 'video_info': {'aspect_ratio': [16, 9], 'duration_millis': 138680, 'variants': [{'bitrate': 832000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1090092682381348864/pu/vid/640x360/lttwOYN-2EEnEmh5.mp4?tag=6'}, {'bitrate': 2176000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1090092682381348864/pu/vid/1280x720/e6npnZZdrPhtsyF0.mp4?tag=6'}, {'bitrate': 256000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1090092682381348864/pu/vid/320x180/ZpnEYB4ilShjiHp7.mp4?tag=6'}, {'content_type': 'application/x-mpegURL', 'url': 'https://video.twimg.com/ext_tw_video/1090092682381348864/pu/pl/xTIaZOhmsl5KqdSI.m3u8?tag=6'}]}, 'features': {}, 'additional_media_info': {'monetizable': False, 'source_user': {'id': 3406938525, 'id_str': '3406938525', 'name': 'thebradfordfile™', 'screen_name': 'thebradfordfile', 'location': 'America', 'description': 'Liberal hypocrisy is a disease.', 'url': 'https://t.co/zYg9wmmP6u', 'entities': {'url': {'urls': [{'url': 'https://t.co/zYg9wmmP6u', 'expanded_url': 'http://thebradfordfile.com', 'display_url': 'thebradfordfile.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 196232, 'friends_count': 2021, 'listed_count': 693, 'created_at': 'Fri Aug 07 09:28:17 +0000 2015', 'favourites_count': 129151, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 93555, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': F ...

# %%
for tweet in user_tweets:
    print("User - " + str(user_id))
    print("Id - " + str(tweet.id))
    print("Created_at - " + str(tweet.created_at))
    print("Text - " + str(tweet.text))
# Out:
# User - 25073877
# Id - 1222931452486148097
# Created_at - 2020-01-30 17:15:53
# Text - RT @realDonaldTrump: https://t.co/66006PDuKf
